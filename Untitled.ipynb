# %% [markdown]
# # Task1

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set seaborn style for better visuals
sns.set(style="whitegrid")

# %%
# Load the dataset
try:
    df = pd.read_csv("student-mat.csv", sep=';')
    print("Dataset loaded successfully.")
except FileNotFoundError:
    print("Error: File not found.")
# Out:
# Dataset loaded successfully.

# %%
# Display the first 5 rows
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# Check for structure, data types and missing values
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# Clean data - drop rows with missing values (if any)
df_cleaned = df.dropna()
print(f"Rows after dropping missing values: {df_cleaned.shape[0]}")
# Out:
# Rows after dropping missing values: 395

# %% [markdown]
# # Task 2: Basic Data Analysis

# %%
# Summary statistics for numeric columns
df_cleaned.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# Grouping by 'sex' to see performance based on gender
grouped_by_sex = df_cleaned.groupby('sex')[['G1', 'G2', 'G3']].mean()
grouped_by_sex
# Out:
#             G1         G2         G3
# sex
# F    10.620192  10.389423   9.966346
# M    11.229947  11.074866  10.914439

# %% [raw]
# from the above statistics we will notice that Male students (M) performed better
# on average across all three grading periods than female students (F).

# %%
# Grouping by 'studytime' and calculating mean final grade
grouped_by_study = df_cleaned.groupby('studytime')['G3'].mean()
grouped_by_study
# Out:
# studytime
# 1    10.047619
# 2    10.171717
# 3    11.400000
# 4    11.259259
# Name: G3, dtype: float64

# %% [raw]
# Study Time Level	Avg. Final Grade (G3)
# 1 (<2 hrs)	        10.05
# 2 (2–5 hrs)	        10.17
# 3 (5–10 hrs)	    11.40
# 4 (>10 hrs)	        11.26
#
#
# Insight:
# There's a positive correlation between study time and performance — students who study more tend to score higher.
#
# The highest average (11.40) is among those who study 5–10 hours/week.
#
# Interestingly, students studying >10 hours/week have a slightly lower average (11.26) than the 5–10 hour group. This could suggest:
#
# They might be compensating for weaker performance or lack of understanding.
#
# Or even experiencing burnout or inefficient study strategies.

# %% [markdown]
# # Task 3: Visualizations

# %%
# Line Chart - G3 (final grade) by student index to see performance trend

plt.figure(figsize=(10,5))
plt.plot(df_cleaned.index, df_cleaned['G3'], color='purple')
plt.title("Final Grade Trend of Students")
plt.xlabel("Student Index")
plt.ylabel("Final Grade (G3)")
plt.grid(True)
plt.show()

# %%
# Bar Chart - Average Final Grade by Study Time

plt.figure(figsize=(8,6))
sns.barplot(x=grouped_by_study.index, y=grouped_by_study.values, palette='Blues_d')
plt.title("Average Final Grade by Study Time")
plt.xlabel("Study Time (hours per week)")
plt.ylabel("Average Final Grade (G3)")
plt.show()

# %%
# Histogram - Distribution of Final Grades

plt.figure(figsize=(8,6))
plt.hist(df_cleaned['G3'], bins=10, color='teal', edgecolor='black')
plt.title("Distribution of Final Grades")
plt.xlabel("Final Grade (G3)")
plt.ylabel("Number of Students")
plt.show()

# %%
# Scatter Plot - Relationship between Absences and Final Grade

plt.figure(figsize=(8,6))
sns.scatterplot(x='absences', y='G3', data=df_cleaned, hue='sex')
plt.title("Absences vs Final Grade")
plt.xlabel("Number of Absences")
plt.ylabel("Final Grade (G3)")
plt.legend(title="Sex")
plt.show()
